# %%
a = 48
b = 18 
if b == 0: 
    print(a) 
print(gcd(b,a%b))

#gcd(a,b): if b == 0: return a return gcd(b,a%b)gcd(48,18)
# Out:
# 6

# %%
def gcd(a: int, b: int) -> int:
    """
    find the Greatest Common Divisor (GCD) of two numbers using recursion.
    
    Args:
        gcd (int): integers given by user
        
    Returns:
        int: Greatest commmon division 
        
    """

    # Data Validation
    if not isinstance(a, int) or not isinstance(b, int):
        raise TypeError("Inputs must be integers")

    # Logic
    if b == 0:
        return a
    return gcd(b, a % b)


# -------- Main Execution --------
if __name__ == "__main__":
    try:
        result = gcd(48, 12)
        print(f"Greatest Common Divisor is: {result}")
    except TypeError as e:
        print("Error:", e)
# Out:
# Greatest Common Divisor is: 12
